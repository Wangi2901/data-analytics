# %% [markdown]
# # 4. Feature Engineering – Data Understanding und Data Preparation
# ## Anforderungen an Projektumsetzung: Feature Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

apps = pd.read_csv("Daten/Google-Playstore.csv")

# %% [markdown]
# ---
# **AUFGABE:**
#
# Erstellen Sie mindestens 2 neue Features.

# %%
# Feature 1:
apps['Rating_bins'] = pd.cut(apps.Rating, [0.0, 0.99, 2.0, 3.0, 4.0, 5.0], include_lowest=True).head()
apps.head()
# Out:
#    Unnamed: 0                                           App Name  \
# 0           0                                            Gakondo
# 1           1                                Ampere Battery Info
# 2           2                                             Vibook
# 3           3  Smart City Trichy Public Service Vehicles 17UC...
# 4           4                                            GROW.me
#
#         Category  Rating  Number of Rating Installs  Minimum Installs  \
# 0      Adventure     0.0               0.0      10+              10.0
# 1          Tools     4.4              64.0   5,000+            5000.0
# 2   Productivity     0.0               0.0      50+              50.0
# 3  Communication     5.0               5.0      10+              10.0
# 4          Tools     0.0               0.0     100+             100.0
#
#    Maximum Installs  Free of Charge  App Price  ...  \
# 0                15            True        0.0  ...
# 1              7662            True        0.0  ...
# 2                58            True        0.0  ...
# 3                19            True        0.0  ...
# 4               478            True        0.0  ...
#
#                         Developer Id                 Developer Website  \
# 0  Jean Confident Irénée NIYIZIBYOSE       https://beniyizibyose.tk/#/
# 1                         Webserveis   https://webserveis.netlify.app/
# 2                         Cabin Crew                               NaN
# 3                Climate Smart Tech2  http://www.climatesmarttech.com/
# 4              Rafal Milek-Horodyski       http://www.horodyski.com.pl
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice     Rating_bins
# 0            False          False  (-0.001, 0.99]
# 1            False          False      (4.0, 5.0]
# 2            False          False  (-0.001, 0.99]
# 3            False          False      (4.0, 5.0]
# 4            False          False  (-0.001, 0.99]
#
# [5 rows x 25 columns]

# %%
# Feature 2
pd.get_dummies(apps['Ad Supported']).head()
# Out:
#    False  True
# 0      1     0
# 1      0     1
# 2      1     0
# 3      0     1
# 4      1     0

# %%
apps['Price_bins'] = pd.cut(apps['App Price'], [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0, 200.0, 300.0, 400.0], include_lowest=True)
apps.head()
# Out:
#    Unnamed: 0                                           App Name  \
# 0           0                                            Gakondo
# 1           1                                Ampere Battery Info
# 2           2                                             Vibook
# 3           3  Smart City Trichy Public Service Vehicles 17UC...
# 4           4                                            GROW.me
#
#         Category  Rating  Number of Rating Installs  Minimum Installs  \
# 0      Adventure     0.0               0.0      10+              10.0
# 1          Tools     4.4              64.0   5,000+            5000.0
# 2   Productivity     0.0               0.0      50+              50.0
# 3  Communication     5.0               5.0      10+              10.0
# 4          Tools     0.0               0.0     100+             100.0
#
#    Maximum Installs  Free of Charge  App Price  ...  \
# 0                15            True        0.0  ...
# 1              7662            True        0.0  ...
# 2                58            True        0.0  ...
# 3                19            True        0.0  ...
# 4               478            True        0.0  ...
#
#                   Developer Website      Released  Last Updated  \
# 0       https://beniyizibyose.tk/#/  Feb 26, 2020  Feb 26, 2020
# 1   https://webserveis.netlify.app/  May 21, 2020  May 06, 2021
# 2                               NaN   Aug 9, 2019  Aug 19, 2019
# 3  http://www.climatesmarttech.com/  Sep 10, 2018  Oct 13, 2018
# 4       http://www.horodyski.com.pl  Feb 21, 2020  Nov 12, 2018
#
#   Content Rating                                     Privacy Policy  \
# 0       Everyone                 https://beniyizibyose.tk/projects/
# 1       Everyone  https://dev4phones.wordpress.com/licencia-de-uso/
# 2       Everyone  https://www.vietnamairlines.com/vn/en/terms-an...
# 3       Everyone                                                NaN
# 4       Everyone                        http://www.horodyski.com.pl
#
#   Ad Supported In App Purchases Editors Choice     Rating_bins      Price_bins
# 0        False            False          False  (-0.001, 0.99]  (-0.001, 10.0]
# 1         True            False          False      (4.0, 5.0]  (-0.001, 10.0]
# 2        False            False          False  (-0.001, 0.99]  (-0.001, 10.0]
# 3         True            False          False      (4.0, 5.0]  (-0.001, 10.0]
# 4        False            False          False  (-0.001, 0.99]  (-0.001, 10.0]
#
# [5 rows x 26 columns]

# %% [markdown]
# ---
# **AUFGABE:**
#
# Untersuchen Sie die Korrelationen gesamthaft und graphisch für mindestens 2 Feature-Kombinationen.

# %%
# Verwerende Daten aus Abschnitt 2.) Datenexploration
apps_in_kb = apps.copy()
apps_in_kb = apps[apps.Size.str.contains('k', na=False)].copy()
apps_in_kb["Size"]

apps_in_kb["Size"] = apps_in_kb["Size"].str.replace("k", "")
apps_in_kb["Size"] = apps_in_kb["Size"].str.replace(",", "")
apps_in_kb["Size"]= pd.to_numeric(apps_in_kb["Size"], errors='raise')
apps_in_kb["Size"] = apps_in_kb["Size"] / 1000.0
apps_in_kb["Size"]

apps_in_mb = apps.copy()
apps_in_mb = apps_in_mb[apps_in_mb.Size.str.contains('M', na=False)].copy()
apps_in_mb["Size"] = apps_in_mb["Size"].str.replace("M", "")
apps_in_mb["Size"] = apps_in_mb["Size"].str.replace(",", "")
apps_in_mb["Size"]= pd.to_numeric(apps_in_mb["Size"], errors='raise')

apps_varies = apps.copy()
apps_varies = apps_varies[apps_varies.Size.str.contains('Varies with device', na=False)].copy()
apps_varies["Size"] = apps_varies["Size"].str.replace("Varies with device", "0.0")
apps_varies["Size"]= pd.to_numeric(apps_varies["Size"], errors='raise')

apps_concated = pd.concat([apps_in_kb, apps_in_mb, apps_varies], ignore_index = False )
apps_concated.Size  # NaN Werte nicht enthalten
apps_concated = pd.concat([apps_in_kb, apps_in_mb, apps_varies], ignore_index = False )
apps_concated.Size  # NaN Werte nicht enthalten

size = apps_concated.Size

# Verwende Daten aus Abschnitt 3.) Datentransformation

conv_in_mb = apps.merge(size, left_index = True, right_index = True)
conv_in_mb.head()
# Out:
#    Unnamed: 0                                           App Name  \
# 0           0                                            Gakondo
# 1           1                                Ampere Battery Info
# 2           2                                             Vibook
# 3           3  Smart City Trichy Public Service Vehicles 17UC...
# 4           4                                            GROW.me
#
#         Category  Rating  Number of Rating Installs  Minimum Installs  \
# 0      Adventure     0.0               0.0      10+              10.0
# 1          Tools     4.4              64.0   5,000+            5000.0
# 2   Productivity     0.0               0.0      50+              50.0
# 3  Communication     5.0               5.0      10+              10.0
# 4          Tools     0.0               0.0     100+             100.0
#
#    Maximum Installs  Free of Charge  App Price  ...      Released  \
# 0                15            True        0.0  ...  Feb 26, 2020
# 1              7662            True        0.0  ...  May 21, 2020
# 2                58            True        0.0  ...   Aug 9, 2019
# 3                19            True        0.0  ...  Sep 10, 2018
# 4               478            True        0.0  ...  Feb 21, 2020
#
#    Last Updated Content Rating  \
# 0  Feb 26, 2020       Everyone
# 1  May 06, 2021       Everyone
# 2  Aug 19, 2019       Everyone
# 3  Oct 13, 2018       Everyone
# 4  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice     Rating_bins      Price_bins Size_y
# 0            False          False  (-0.001, 0.99]  (-0.001, 10.0]   10.0
# 1            False          False      (4.0, 5.0]  (-0.001, 10.0]    2.9
# 2            False          False  (-0.001, 0.99]  (-0.001, 10.0]    3.7
# 3            False          False      (4.0, 5.0]  (-0.001, 10.0]    1.8
# 4            False          False  (-0.001, 0.99]  (-0.001, 10.0]    6.2
#
# [5 rows x 27 columns]

# %%
conv_in_mb.corr()
# Out:
#                   Unnamed: 0    Rating  Number of Rating  Minimum Installs  \
# Unnamed: 0          1.000000 -0.000597          0.000179          0.001141
# Rating             -0.000597  1.000000          0.013030          0.011212
# Number of Rating    0.000179  0.013030          1.000000          0.545278
# Minimum Installs    0.001141  0.011212          0.545278          1.000000
# Maximum Installs    0.001067  0.012612          0.547573          0.954037
# Free of Charge      0.000768 -0.010748          0.001409          0.001622
# App Price           0.000415 -0.003688         -0.000410         -0.000460
# Revenue            -0.000431  0.006061          0.013279          0.000545
# Ad Supported       -0.000791  0.160505          0.005287          0.002247
# In App Purchases   -0.000635  0.153810          0.025706          0.014169
# Editors Choice      0.000317  0.019463          0.137222          0.059914
# Size_y              0.000191  0.046177          0.013239          0.004124
#
#                   Maximum Installs  Free of Charge  App Price   Revenue  \
# Unnamed: 0                0.001067        0.000768   0.000415 -0.000431
# Rating                    0.012612       -0.010748  -0.003688  0.006061
# Number of Rating          0.547573        0.001409  -0.000410  0.013279
# Minimum Installs          0.954037        0.001622  -0.000460  0.000545
# Maximum Installs          1.000000        0.001815  -0.000515  0.001127
# Free of Charge            0.001815        1.000000  -0.278777 -0.044165
# App Price                -0.000515       -0.278777   1.000000  0.027985
# Revenue                   0.001127       -0.044165   0.027985  1.000000
# Ad Supported              0.002879        0.123626  -0.034269 -0.004666
# In App Purchases          0.016093        0.008689  -0.002668  0.006645
# Editors Choice            0.064216       -0.003167   0.000506  0.042314
# Size_y                    0.005009       -0.003471   0.003530  0.003224
#
#                   Ad Supported  In App Purchases  Editors Choice    Size_y
# Unnamed: 0           -0.000791         -0.000635        0.000317  0.000191
# Rating                0.160505          0.153810        0.019463  0.046177
# Number of Rating      0.005287          0.025706        0.137222  0.013239
# Minimum Installs      0.002247          0.014169        0.059914  0.004124
# Maximum Installs      0.002879          0.016093        0.064216  0.005009
# Free of Charge        0.123626          0.008689       -0.003167 -0.003471
# App Price            -0.034269         -0.002668        0.000506  0.003530
# Revenue              -0.004666          0.006645        0.042314  0.003224
# Ad Supported          1.000000          0.138316        0.005708 -0.042874
# In App Purchases      0.138316          1.000000        0.045984  0.165520
# Editors Choice        0.005708          0.045984        1.000000  0.038142
# Size_y               -0.042874          0.165520        0.038142  1.000000

# %%
sns.heatmap(apps.corr(), annot = True, fmt='.2f', cmap= 'YlGnBu')
plt.show()

# %%
two_bins = apps.pivot_table(index='Rating_bins', columns='Price_bins', values='App Id', aggfunc='count', fill_value=0)
two_bins.head()
# Out:
# Price_bins      (-0.001, 10.0]  (10.0, 20.0]  (20.0, 30.0]  (30.0, 40.0]  \
# Rating_bins
# (-0.001, 0.99]               3             0             0             0
# (0.99, 2.0]                  0             0             0             0
# (2.0, 3.0]                   0             0             0             0
# (3.0, 4.0]                   0             0             0             0
# (4.0, 5.0]                   2             0             0             0
#
# Price_bins      (40.0, 50.0]  (50.0, 60.0]  (60.0, 70.0]  (70.0, 80.0]  \
# Rating_bins
# (-0.001, 0.99]             0             0             0             0
# (0.99, 2.0]                0             0             0             0
# (2.0, 3.0]                 0             0             0             0
# (3.0, 4.0]                 0             0             0             0
# (4.0, 5.0]                 0             0             0             0
#
# Price_bins      (80.0, 90.0]  (90.0, 100.0]  (100.0, 200.0]  (200.0, 300.0]  \
# Rating_bins
# (-0.001, 0.99]             0              0               0               0
# (0.99, 2.0]                0              0               0               0
# (2.0, 3.0]                 0              0               0               0
# (3.0, 4.0]                 0              0               0               0
# (4.0, 5.0]                 0              0               0               0
#
# Price_bins      (300.0, 400.0]
# Rating_bins
# (-0.001, 0.99]               0
# (0.99, 2.0]                  0
# (2.0, 3.0]                   0
# (3.0, 4.0]                   0
# (4.0, 5.0]                   0

# %%
# Erstellen der Heatmap
plt.figure(figsize=(15,6))
sns.heatmap(two_bins, annot=True, fmt='d', linewidths=.5,cmap="YlGnBu")
plt.show()

# %% [markdown]
# ---
# **AUFGABE:**
#
# Erstellen/Konvertieren Sie eine Time Series.

# %%
# `Released`-Spalte in Datetime-Format umwandeln 
apps['Released']      = pd.to_datetime(apps['Released'], format='%b %d, %Y')
apps['Last Updated']  = pd.to_datetime(apps['Last Updated'], format='%b %d, %Y')
apps['Released Year'] = pd.DatetimeIndex(apps['Released']).year
apps.head()
# Out:
#    Unnamed: 0                                           App Name  \
# 0           0                                            Gakondo
# 1           1                                Ampere Battery Info
# 2           2                                             Vibook
# 3           3  Smart City Trichy Public Service Vehicles 17UC...
# 4           4                                            GROW.me
#
#         Category  Rating  Number of Rating Installs  Minimum Installs  \
# 0      Adventure     0.0               0.0      10+              10.0
# 1          Tools     4.4              64.0   5,000+            5000.0
# 2   Productivity     0.0               0.0      50+              50.0
# 3  Communication     5.0               5.0      10+              10.0
# 4          Tools     0.0               0.0     100+             100.0
#
#    Maximum Installs  Free of Charge  App Price  ...   Released  Last Updated  \
# 0                15            True        0.0  ... 2020-02-26    2020-02-26
# 1              7662            True        0.0  ... 2020-05-21    2021-05-06
# 2                58            True        0.0  ... 2019-08-09    2019-08-19
# 3                19            True        0.0  ... 2018-09-10    2018-10-13
# 4               478            True        0.0  ... 2020-02-21    2018-11-12
#
#   Content Rating                                     Privacy Policy  \
# 0       Everyone                 https://beniyizibyose.tk/projects/
# 1       Everyone  https://dev4phones.wordpress.com/licencia-de-uso/
# 2       Everyone  https://www.vietnamairlines.com/vn/en/terms-an...
# 3       Everyone                                                NaN
# 4       Everyone                        http://www.horodyski.com.pl
#
#   Ad Supported In App Purchases Editors Choice     Rating_bins  \
# 0        False            False          False  (-0.001, 0.99]
# 1         True            False          False      (4.0, 5.0]
# 2        False            False          False  (-0.001, 0.99]
# 3         True            False          False      (4.0, 5.0]
# 4        False            False          False  (-0.001, 0.99]
#
#        Price_bins Released Year
# 0  (-0.001, 10.0]        2020.0
# 1  (-0.001, 10.0]        2020.0
# 2  (-0.001, 10.0]        2019.0
# 3  (-0.001, 10.0]        2018.0
# 4  (-0.001, 10.0]        2020.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ---
# **AUFGABE:**
#
# Erstellen Sie eine Analyse basierend auf den Zeitdaten.

# %%
# Berechne Zeitraum zwischen Releas und lezten Update - Rundung auf ganze Tage
delta = (apps['Last Updated'] - apps['Released']).dropna()
 
negative_days = delta[delta < '0 days']
i = negative_days.index

# Lösche aller Daten, die negative Tage haben --> Anz: 9881 --> Werden nichts berücksichtigt, weil das Verhältniss zu 2.3 Mio. zu klein ist 
delta.drop(i, inplace=True)
delta
# Out:
# 0            0 days
# 1          350 days
# 2           10 days
# 3           33 days
# 5          361 days
#              ...
# 2312938    206 days
# 2312940     16 days
# 2312941      0 days
# 2312942   1738 days
# 2312943     10 days
# Length: 2232010, dtype: timedelta64[ns]

# %%
delta.value_counts()
# Out:
# 0 days       475241
# 1 days       157354
# 2 days        16877
# 4 days        14827
# 3 days        14613
#               ...
# 4145 days         1
# 4100 days         1
# 3951 days         1
# 4062 days         1
# 4036 days         1
# Length: 4110, dtype: int64

# %%
# Plotten der Werteverteilung von Apps, die nach 30 Tagen ein Update nach dem Release getätigt haben
delta[delta >= pd.Timedelta(30, 'D')].value_counts().plot()
plt.show()
